# %%
import os
import pandas as pd
import numpy as np

# %%
#top_songs=pd.read_csv("top_songs.csv")
top_streaming = pd.read_csv("top_streaming.csv")

#top_songs
top_streaming
# Out:
#      Unnamed: 0  Song Rank                           Song Title  \
# 0             0          1                     \nHarlem Shake\n
# 1             1          2                    \nGangnam Style\n
# 2             2          3                      \nThrift Shop\n
# 3             3          4                      \nRadioactive\n
# 4             4          5                    \nWe Can't Stop\n
# ..          ...        ...                                  ...
# 520         520         71                       \nHigh Hopes\n
# 521         521         72                              \nME!\n
# 522         522         73             \nHIGHEST IN THE ROOM\n
# 523         523         74  \nAll I Want For Christmas Is You\n
# 524         524         75                        \nCon Calma\n
#
#                                       Song Artist  Song Year
# 0                                  \n\nBaauer\n\n       2013
# 1                                     \n\nPSY\n\n       2013
# ...

# %%
top_streaming["Song Title"]=top_streaming["Song Title"].str.replace("\n", "")
top_streaming["Song Artist"]=top_streaming["Song Artist"].str.replace("\n\n", "")
top_streaming["Song Artist"]=top_streaming["Song Artist"].str.replace("\n", "")

top_streaming
# Out:
#      Unnamed: 0  Song Rank                       Song Title  \
# 0             0          1                     Harlem Shake
# 1             1          2                    Gangnam Style
# 2             2          3                      Thrift Shop
# 3             3          4                      Radioactive
# 4             4          5                    We Can't Stop
# ..          ...        ...                              ...
# 520         520         71                       High Hopes
# 521         521         72                              ME!
# 522         522         73             HIGHEST IN THE ROOM
# 523         523         74  All I Want For Christmas Is You
# 524         524         75                        Con Calma
#
#                                   Song Artist  Song Year
# 0                                      Baauer       2013
# 1                                         PSY       2013
# 2      Macklemore & Ryan Lewis Featuring Wanz       2013
# ...

# %%
top_streaming = top_streaming[["Song Rank", "Song Title", "Song Artist", "Song Year"]]

top_streaming.to_csv('Top Streaming Songs Modified.csv', index = False)
